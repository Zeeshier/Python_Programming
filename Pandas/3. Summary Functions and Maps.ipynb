# %% [markdown]
# # Summary Functions
# Summary functions in pandas are used to summarize and provide insights

# %%
import pandas as pd
data = pd.read_csv('Cuisine_rating.csv')
data.head()
# Out:
#    User ID  Area code            Location  Gender   YOB Marital Status  \
# 0        1        153  Upper East Side,NY  Female  2006         Single
# 1        2        123       St. George,NY  Female  1991        Married
# 2        3        122  Upper West Side,NY    Male  1977         Single
# 3        4        153  Upper East Side,NY  Female  1956        Married
# 4        5        129     Central Park,NY    Male  1997         Single
#
#        Activity  Budget  Cuisines  Alcohol     Smoker  Food Rating  \
# 0  Professional       3  Japanese     Never     Never            5
# 1       Student       3    Indian     Never  Socially            1
# 2       Student       5   Seafood     Often     Often            5
# 3  Professional       5  Japanese     Never  Socially            3
# 4       Student       4  Filipino  Socially     Never            2
#
#    Service Rating  Overall Rating Often A S
# 0               4             4.5        No
# 1               1             1.0        No
# ...

# %%
# describe() : for Numerical data

data['Food Rating'].describe()
# Out:
# count    200.000000
# mean       3.220000
# std        1.411226
# min        1.000000
# 25%        2.000000
# 50%        3.000000
# 75%        5.000000
# max        5.000000
# Name: Food Rating, dtype: float64

# %%
# describe() : for string  data, output will be change

data.Cuisines.describe()
# Out:
# count          200
# unique           7
# top       Japanese
# freq            36
# Name: Cuisines, dtype: object

# %%
# mean()

data['Overall Rating'].mean()
# Out:
# np.float64(3.225)

# %%
#unique() : To see a list of unique values

data.Cuisines.unique()
# Out:
# array(['Japanese', 'Indian', 'Seafood', 'Filipino', 'Italian', 'Chinese',
#        'French'], dtype=object)

# %%
#value_counts() : To see a list of unique values and how often they occur in the dataset

data.Cuisines.value_counts()
# Out:
# Cuisines
# Japanese    36
# French      34
# Filipino    34
# Indian      32
# Chinese     24
# Seafood     22
# Italian     18
# Name: count, dtype: int64

# %% [markdown]
# # Maps

# %%
# map() method : returns a new Series where all the values have been transformed

overall_rating_mean =data['Overall Rating'].mean()
data['Overall Rating'].map(lambda p: p - overall_rating_mean)
# Out:
# 0      1.275
# 1     -2.225
# 2      1.775
# 3     -1.225
# 4     -0.225
#        ...
# 195   -1.725
# 196   -1.725
# 197    0.275
# 198   -0.725
# 199   -0.725
# Name: Overall Rating, Length: 200, dtype: float64

# %%
# apply() : want to transform a whole DataFrame by calling a custom method on each row

def rating(row):
    row['Overall Rating'] = row['Overall Rating'] - overall_rating_mean
    return row

data.apply(rating, axis='columns')
# Out:
#      User ID  Area code            Location  Gender   YOB Marital Status  \
# 0          1        153  Upper East Side,NY  Female  2006         Single
# 1          2        123       St. George,NY  Female  1991        Married
# 2          3        122  Upper West Side,NY    Male  1977         Single
# 3          4        153  Upper East Side,NY  Female  1956        Married
# 4          5        129     Central Park,NY    Male  1997         Single
# ..       ...        ...                 ...     ...   ...            ...
# 195      196        175       St. George,NY  Female  1982         Single
# 196      197        170  Upper West Side,NY  Female  2000        Married
# 197      198        160       St. George,NY  Female  2006         Single
# 198      199        130       St. George,NY    Male  2002        Married
# 199      200        140  Upper East Side,NY    Male  2005        Married
#
#          Activity  Budget  Cuisines  Alcohol     Smoker  Food Rating  \
# ...

# %% [markdown]
# Note that map() and apply() return new, transformed Series and DataFrames, respectively. They don't modify the original data they're called on
