# %%
import pandas as pd

data = pd.read_csv("Cuisine_rating.csv")

# %% [markdown]
# # Native accessors

# %%
data
# Out:
#      User ID  Area code            Location  Gender   YOB Marital Status  \
# 0          1        153  Upper East Side,NY  Female  2006         Single
# 1          2        123       St. George,NY  Female  1991        Married
# 2          3        122  Upper West Side,NY    Male  1977         Single
# 3          4        153  Upper East Side,NY  Female  1956        Married
# 4          5        129     Central Park,NY    Male  1997         Single
# ..       ...        ...                 ...     ...   ...            ...
# 195      196        175       St. George,NY  Female  1982         Single
# 196      197        170  Upper West Side,NY  Female  2000        Married
# 197      198        160       St. George,NY  Female  2006         Single
# 198      199        130       St. George,NY    Male  2002        Married
# 199      200        140  Upper East Side,NY    Male  2005        Married
#
#          Activity  Budget  Cuisines  Alcohol     Smoker  Food Rating  \
# ...

# %%
#Access the property of an object by accessing it as an attribute

data.Gender
# Out:
# 0      Female
# 1      Female
# 2        Male
# 3      Female
# 4        Male
#         ...
# 195    Female
# 196    Female
# 197    Female
# 198      Male
# 199      Male
# Name: Gender, Length: 200, dtype: object

# %%
#Access values using the indexing 

data['Gender']
# Out:
# 0      Female
# 1      Female
# 2        Male
# 3      Female
# 4        Male
#         ...
# 195    Female
# 196    Female
# 197    Female
# 198      Male
# 199      Male
# Name: Gender, Length: 200, dtype: object

# %%
data['Gender'][5]
# Out:
# 'Male'

# %% [markdown]
# # Indexing

# %% [markdown]
# **Index-based selection**

# %%
#To select the first row of data

data.iloc[0]
# Out:
# User ID                            1
# Area code                        153
# Location          Upper East Side,NY
# Gender                        Female
# YOB                             2006
# Marital Status                Single
# Activity                Professional
# Budget                             3
# Cuisines                    Japanese
# Alcohol                        Never
# Smoker                         Never
# Food Rating                        5
# Service Rating                     4
# Overall Rating                   4.5
# Often A S                         No
# Name: 0, dtype: object

# %%
#To get a column with iloc

data.iloc[:, 3]
# Out:
# 0      Female
# 1      Female
# 2        Male
# 3      Female
# 4        Male
#         ...
# 195    Female
# 196    Female
# 197    Female
# 198      Male
# 199      Male
# Name: Gender, Length: 200, dtype: object

# %%
#to indicate a range of values

data.iloc[:5, 2]
# Out:
# 0    Upper East Side,NY
# 1         St. George,NY
# 2    Upper West Side,NY
# 3    Upper East Side,NY
# 4       Central Park,NY
# Name: Location, dtype: object

# %%
#to select just the second and third entries

data.iloc[1:3, 2]
# Out:
# 1         St. George,NY
# 2    Upper West Side,NY
# Name: Location, dtype: object

# %%
#to pass a list

data.iloc[[4,5,6,7], 3]
# Out:
# 4      Male
# 5      Male
# 6    Female
# 7    Female
# Name: Gender, dtype: object

# %%
# get end of the values of dataset

data.iloc[-5:]
# Out:
#      User ID  Area code            Location  Gender   YOB Marital Status  \
# 195      196        175       St. George,NY  Female  1982         Single
# 196      197        170  Upper West Side,NY  Female  2000        Married
# 197      198        160       St. George,NY  Female  2006         Single
# 198      199        130       St. George,NY    Male  2002        Married
# 199      200        140  Upper East Side,NY    Male  2005        Married
#
#          Activity  Budget  Cuisines Alcohol     Smoker  Food Rating  \
# 195  Professional       4    French    Never  Socially            1
# 196       Student       4   Chinese    Never     Often            1
# 197  Professional       5  Japanese    Never     Often            5
# 198       Student       3  Filipino    Never  Socially            3
# 199       Student       4    French    Never     Never            3
#
#      Service Rating  Overall Rating Often A S
# 195               2             1.5        No
# ...

# %% [markdown]
# **Label-based selection**

# %%
#to get the first entry

data.loc[0, 'Location']
# Out:
# 'Upper East Side,NY'

# %%
data.loc[2:6, ['Area code', 'Location', 'YOB']]
# Out:
#    Area code            Location   YOB
# 2        122  Upper West Side,NY  1977
# 3        153  Upper East Side,NY  1956
# 4        129     Central Park,NY  1997
# 5        111      China Town, NY  1995
# 6        111      China Town, NY  1977

# %% [markdown]
# # Manipulating the index

# %%
# set_index() method : manipulate the index in any way

data.set_index('User ID')
# Out:
#          Area code            Location  Gender   YOB Marital Status  \
# User ID
# 1              153  Upper East Side,NY  Female  2006         Single
# 2              123       St. George,NY  Female  1991        Married
# 3              122  Upper West Side,NY    Male  1977         Single
# 4              153  Upper East Side,NY  Female  1956        Married
# 5              129     Central Park,NY    Male  1997         Single
# ...            ...                 ...     ...   ...            ...
# 196            175       St. George,NY  Female  1982         Single
# 197            170  Upper West Side,NY  Female  2000        Married
# 198            160       St. George,NY  Female  2006         Single
# 199            130       St. George,NY    Male  2002        Married
# 200            140  Upper East Side,NY    Male  2005        Married
#
#              Activity  Budget  Cuisines  Alcohol     Smoker  Food Rating  \
# User ID
# ...

# %% [markdown]
# # Conditional selection

# %%
data.Gender == 'Male'

# This operation produced a Series of True/False booleans
# Out:
# 0      False
# 1      False
# 2       True
# 3      False
# 4       True
#        ...
# 195    False
# 196    False
# 197    False
# 198     True
# 199     True
# Name: Gender, Length: 200, dtype: bool

# %%
#  to select the relevant data

data.loc[data.Gender == 'Male']
# Out:
#      User ID  Area code            Location Gender   YOB Marital Status  \
# 2          3        122  Upper West Side,NY   Male  1977         Single
# 4          5        129     Central Park,NY   Male  1997         Single
# 5          6        111      China Town, NY   Male  1995         Single
# 8          9        107        Riverdale,NY   Male  1965         Single
# 9         10        129     Central Park,NY   Male  1995         Single
# ..       ...        ...                 ...    ...   ...            ...
# 191      192        178      China Town, NY   Male  1969       Divorced
# 192      193        105       St. George,NY   Male  2000         Single
# 194      195        107      China Town, NY   Male  1974        Married
# 198      199        130       St. George,NY   Male  2002        Married
# 199      200        140  Upper East Side,NY   Male  2005        Married
#
#          Activity  Budget  Cuisines  Alcohol     Smoker  Food Rating  \
# ...

# %%
# Use the ampersand (&) to perform element-wise logical AND

data.loc[(data.Cuisines == 'Seafood') & (data['Overall Rating'] >= 4)]
# Out:
#      User ID  Area code            Location  Gender   YOB Marital Status  \
# 2          3        122  Upper West Side,NY    Male  1977         Single
# 23        24        154     Market City, NY    Male  1974       Divorced
# 29        30        154     Market City, NY  Female  1988        Married
# 78        79        111      China Town, NY    Male  1965        Married
# 123      124        113     Market City, NY    Male  1974       Divorced
# 129      130        158     Market City, NY  Female  1988        Married
# 178      179        149      China Town, NY    Male  1965        Married
#
#          Activity  Budget Cuisines  Alcohol     Smoker  Food Rating  \
# 2         Student       5  Seafood     Often     Often            5
# 23   Professional       1  Seafood  Socially     Often            5
# 29        Student       5  Seafood     Never  Socially            4
# 78   Professional       3  Seafood     Often     Often            5
# ...

# %%
# Use the pipe (|) to perform element-wise logical OR

data.loc[(data.Gender == 'Seafood') | (data['Overall Rating']>= 4)]
# Out:
#      User ID  Area code            Location  Gender   YOB Marital Status  \
# 0          1        153  Upper East Side,NY  Female  2006         Single
# 2          3        122  Upper West Side,NY    Male  1977         Single
# 12        13        123       St. George,NY  Female  2006         Single
# 18        19        129     Central Park,NY    Male  2001         Single
# 20        21        123       St. George,NY  Female  2009         Single
# ..       ...        ...                 ...     ...   ...            ...
# 184      185        158  Upper East Side,NY  Female  1978       Divorced
# 187      188        137     Central Park,NY  Female  2007         Single
# 188      189        154  Upper West Side,NY  Female  2003        Married
# 189      190        167       St. George,NY    Male  1988       Divorced
# 192      193        105       St. George,NY    Male  2000         Single
#
#          Activity  Budget  Cuisines  Alcohol     Smoker  Food Rating  \
# ...

# %%
# .isin : Select data whose value "is in" a list of values

data.loc[data.Cuisines.isin(['Indian', 'French'])]
# Out:
#      User ID  Area code            Location  Gender   YOB Marital Status  \
# 1          2        123       St. George,NY  Female  1991        Married
# 6          7        111      China Town, NY  Female  1977        Married
# 10        11        123       St. George,NY  Female  1975        Married
# 15        16        153  Upper East Side,NY  Female  1956        Married
# 20        21        123       St. George,NY  Female  2009         Single
# ..       ...        ...                 ...     ...   ...            ...
# 191      192        178      China Town, NY    Male  1969       Divorced
# 192      193        105       St. George,NY    Male  2000         Single
# 194      195        107      China Town, NY    Male  1974        Married
# 195      196        175       St. George,NY  Female  1982         Single
# 199      200        140  Upper East Side,NY    Male  2005        Married
#
#          Activity  Budget Cuisines  Alcohol     Smoker  Food Rating  \
# ...

# %%
# isnull & notnull

data.loc[data['Service Rating'].notnull()]
# Out:
#      User ID  Area code            Location  Gender   YOB Marital Status  \
# 0          1        153  Upper East Side,NY  Female  2006         Single
# 1          2        123       St. George,NY  Female  1991        Married
# 2          3        122  Upper West Side,NY    Male  1977         Single
# 3          4        153  Upper East Side,NY  Female  1956        Married
# 4          5        129     Central Park,NY    Male  1997         Single
# ..       ...        ...                 ...     ...   ...            ...
# 195      196        175       St. George,NY  Female  1982         Single
# 196      197        170  Upper West Side,NY  Female  2000        Married
# 197      198        160       St. George,NY  Female  2006         Single
# 198      199        130       St. George,NY    Male  2002        Married
# 199      200        140  Upper East Side,NY    Male  2005        Married
#
#          Activity  Budget  Cuisines  Alcohol     Smoker  Food Rating  \
# ...

# %% [markdown]
# # Assigning data
